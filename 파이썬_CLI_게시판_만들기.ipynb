# %% [markdown]
# <a href="https://colab.research.google.com/github/kyungminkang0909/make_python_CLI_board/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_CLI_%EA%B2%8C%EC%8B%9C%ED%8C%90_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("== CLI 게시판 실행 ==")
input("명령어 ) ")
input("제목 : ")
input("내용 : ")
print("1번 글이 생성 되었습니다.")
input("명령어 ) ")
input("제목 : ")
input("내용 : ")
print("2번 글이 생성 되었습니다.")
input("명령어 ) ")
print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 :~~~
# 내용 :!!!
# 1번 글이 생성 되었습니다.
# 명령어 ) article write
# 제목 :###
# 내용 :%%%
# 2번 글이 생성 되었습니다.
# 명령어 )exit
# == CLI 게시판 종료 ==

# %%
print("== CLI 게시판 실행 ==")
while True:
  cmd = input("명령어 ) ")
  if cmd == "article write":
    input("제목 :")
    input("내용 :")
  elif cmd == "exit":
    break
  else:
    print("지원하지 않는 기능입니다.")
print("== CLI 게시판 종료 ==")
